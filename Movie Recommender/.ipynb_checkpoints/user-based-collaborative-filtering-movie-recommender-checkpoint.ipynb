# %% [markdown]
# # User-Based-Collaborative-Filtering-Movie-Recommender
# User-Based Collaborative Filtering is a popular method of making recommendations because it is easy to understand and implement, and can handle very large datasets. It works by finding other users who have similar tastes to the user for whom we want to make recommendations, and then recommending items that those similar users have liked. It is based on the idea that similar users will have similar preferences for items.
# For the Recommender System, following approach is used.

# %% [markdown]
# # Importing necessary packages.
# It is necessary to import the required libraries to perform different operations before writing program.

# %%
#importing necessary packages for the program
import pandas as pd
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

# %% [markdown]
# # Importing Dataset
# After importing necessary libraries, it is necessary to import the required dataset that are to be used to train the system for the accurate result. For this system, two csv files are imported which were extracted from Kaggle. After they were merged into a single variable for better processing of data's for future processes.

# %%
# reading the csv files available and merging them into one for easy processing of dataset
user_ratings = pd.read_csv('ratings_user-item.csv')
movies = pd.read_csv('tagsngenres.csv')
user_ratings = pd.merge(movies,user_ratings)
# print(user_ratings.shape)
user_ratings.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#     tags  userId  rating
# 0  pixar       1     4.0
# 1  pixar       5     4.0
# 2  pixar       7     4.5
# 3  pixar      15     2.5
# 4  pixar      17     4.5

# %% [markdown]
# # Pivoting Table
# After impoting the dataset, it is necessary to pivot the tables from the dataset. pivoting tables of dataset is necessary in collaborative filtering because it allows the efficient calculation of similarities and correlations between users or items, it also makes it easier to extract meaningful insights from the data and make the models more computationally efficient.

# %%
#pivoting the dataset table and checking the before and after columns of dataset
Ratings = user_ratings.pivot_table(index=['userId'],columns=['title'],values='rating')
Ratings.head()
print("Before: ",Ratings.shape)
Ratings = Ratings.dropna(thresh=5, axis=1).fillna(0,axis=1)
print("After: ",Ratings.shape)
# Out:
# Before:  (610, 1545)
# After:  (610, 1119)

# %% [markdown]
# # Correlation of table
# It is necessary for the table to correlate as to reduct the NaN data's existing in the dataset. For this system, Pearson Method is used for the correlation of datasets.
# Pearson correlation algorithm as a memory-based collaborative filtering method overcomes the problem of scalability by calculating the similarity between pairs of items rated by the users, or between pairs of users who rate the same item.

# %%
# computing the pairwise correlation of columns in a DataFrame
corrMatrix = Ratings.corr(method='pearson')
corrMatrix.head(10)
# Out:
# title                                               (500) Days of Summer (2009)  \
# title
# (500) Days of Summer (2009)                                            1.000000
# 10 Cloverfield Lane (2016)                                             0.142471
# 10 Things I Hate About You (1999)                                      0.273989
# 101 Dalmatians (1996)                                                  0.148903
# 101 Dalmatians (One Hundred and One Dalmatians)...                     0.142141
# 12 Angry Men (1957)                                                    0.159756
# 127 Hours (2010)                                                       0.200135
# 13 Going on 30 (2004)                                                  0.297152
# 2001: A Space Odyssey (1968)                                           0.113616
# 21 Grams (2003)                                                        0.094029
#
# title                                               10 Cloverfield Lane (2016)  \
# title
# (500) Days of Summer (2009)                                           0.142471
# 10 Cloverfield Lane (2016)                                            1.000000
# 10 Things I Hate About You (1999)                                    -0.005799
# 101 Dalmatians (1996)                                                 0.006139
# 101 Dalmatians (One Hundred and One Dalmatians)...                   -0.016835
# 12 Angry Men (1957)                                                   0.031704
# 127 Hours (2010)                                                      0.272943
# 13 Going on 30 (2004)                                                -0.027835
# 2001: A Space Odyssey (1968)                                          0.099310
# 21 Grams (2003)                                                      -0.030166
#
# title                                               10 Things I Hate About You (1999)  \
# title
# (500) Days of Summer (2009)                                                  0.273989
# 10 Cloverfield Lane (2016)                                                  -0.005799
# 10 Things I Hate About You (1999)                                            1.000000
# 101 Dalmatians (1996)                                                        0.223481
# 101 Dalmatians (One Hundred and One Dalmatians)...                           0.211473
# 12 Angry Men (1957)                                                          0.011784
# 127 Hours (2010)                                                             0.043383
# 13 Going on 30 (2004)                                                        0.321071
# 2001: A Space Odyssey (1968)                                                 0.085974
# 21 Grams (2003)                                                              0.092169
#
# title                                               101 Dalmatians (1996)  \
# title
# (500) Days of Summer (2009)                                      0.148903
# 10 Cloverfield Lane (2016)                                       0.006139
# 10 Things I Hate About You (1999)                                0.223481
# 101 Dalmatians (1996)                                            1.000000
# 101 Dalmatians (One Hundred and One Dalmatians)...               0.285112
# 12 Angry Men (1957)                                              0.119843
# 127 Hours (2010)                                                 0.029967
# 13 Going on 30 (2004)                                            0.188467
# 2001: A Space Odyssey (1968)                                     0.110844
# 21 Grams (2003)                                                  0.065939
#
# title                                               101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# title
# (500) Days of Summer (2009)                                                                  0.142141
# 10 Cloverfield Lane (2016)                                                                  -0.016835
# 10 Things I Hate About You (1999)                                                            0.211473
# 101 Dalmatians (1996)                                                                        0.285112
# 101 Dalmatians (One Hundred and One Dalmatians)...                                           1.000000
# 12 Angry Men (1957)                                                                          0.134037
# 127 Hours (2010)                                                                            -0.046277
# 13 Going on 30 (2004)                                                                        0.218406
# 2001: A Space Odyssey (1968)                                                                 0.102230
# 21 Grams (2003)                                                                              0.077724
#
# title                                               12 Angry Men (1957)  \
# title
# (500) Days of Summer (2009)                                    0.159756
# 10 Cloverfield Lane (2016)                                     0.031704
# 10 Things I Hate About You (1999)                              0.011784
# 101 Dalmatians (1996)                                          0.119843
# 101 Dalmatians (One Hundred and One Dalmatians)...             0.134037
# 12 Angry Men (1957)                                            1.000000
# 127 Hours (2010)                                               0.058862
# 13 Going on 30 (2004)                                         -0.027672
# 2001: A Space Odyssey (1968)                                   0.195909
# 21 Grams (2003)                                                0.008812
#
# title                                               127 Hours (2010)  \
# title
# (500) Days of Summer (2009)                                 0.200135
# 10 Cloverfield Lane (2016)                                  0.272943
# 10 Things I Hate About You (1999)                           0.043383
# 101 Dalmatians (1996)                                       0.029967
# 101 Dalmatians (One Hundred and One Dalmatians)...         -0.046277
# 12 Angry Men (1957)                                         0.058862
# 127 Hours (2010)                                            1.000000
# 13 Going on 30 (2004)                                       0.043314
# 2001: A Space Odyssey (1968)                                0.140796
# 21 Grams (2003)                                             0.070118
#
# title                                               13 Going on 30 (2004)  \
# title
# (500) Days of Summer (2009)                                      0.297152
# 10 Cloverfield Lane (2016)                                      -0.027835
# 10 Things I Hate About You (1999)                                0.321071
# 101 Dalmatians (1996)                                            0.188467
# 101 Dalmatians (One Hundred and One Dalmatians)...               0.218406
# 12 Angry Men (1957)                                             -0.027672
# 127 Hours (2010)                                                 0.043314
# 13 Going on 30 (2004)                                            1.000000
# 2001: A Space Odyssey (1968)                                     0.040458
# 21 Grams (2003)                                                  0.084832
#
# title                                               2001: A Space Odyssey (1968)  \
# title
# (500) Days of Summer (2009)                                             0.113616
# 10 Cloverfield Lane (2016)                                              0.099310
# 10 Things I Hate About You (1999)                                       0.085974
# 101 Dalmatians (1996)                                                   0.110844
# 101 Dalmatians (One Hundred and One Dalmatians)...                      0.102230
# 12 Angry Men (1957)                                                     0.195909
# 127 Hours (2010)                                                        0.140796
# 13 Going on 30 (2004)                                                   0.040458
# 2001: A Space Odyssey (1968)                                            1.000000
# 21 Grams (2003)                                                         0.152689
#
# title                                               21 Grams (2003)  ...  \
# title                                                                ...
# (500) Days of Summer (2009)                                0.094029  ...
# 10 Cloverfield Lane (2016)                                -0.030166  ...
# 10 Things I Hate About You (1999)                          0.092169  ...
# 101 Dalmatians (1996)                                      0.065939  ...
# 101 Dalmatians (One Hundred and One Dalmatians)...         0.077724  ...
# 12 Angry Men (1957)                                        0.008812  ...
# 127 Hours (2010)                                           0.070118  ...
# 13 Going on 30 (2004)                                      0.084832  ...
# 2001: A Space Odyssey (1968)                               0.152689  ...
# 21 Grams (2003)                                            1.000000  ...
#
# title                                               Yojimbo (1961)  \
# title
# (500) Days of Summer (2009)                               0.029789
# 10 Cloverfield Lane (2016)                                0.036295
# 10 Things I Hate About You (1999)                         0.044099
# 101 Dalmatians (1996)                                    -0.015241
# 101 Dalmatians (One Hundred and One Dalmatians)...        0.154346
# 12 Angry Men (1957)                                       0.138834
# 127 Hours (2010)                                          0.053763
# 13 Going on 30 (2004)                                    -0.026422
# 2001: A Space Odyssey (1968)                              0.220379
# 21 Grams (2003)                                           0.111872
#
# title                                               You Can Count on Me (2000)  \
# title
# (500) Days of Summer (2009)                                           0.049562
# 10 Cloverfield Lane (2016)                                           -0.017991
# 10 Things I Hate About You (1999)                                     0.147730
# 101 Dalmatians (1996)                                                 0.045174
# 101 Dalmatians (One Hundred and One Dalmatians)...                    0.142805
# 12 Angry Men (1957)                                                   0.066496
# 127 Hours (2010)                                                     -0.020360
# 13 Going on 30 (2004)                                                 0.058544
# 2001: A Space Odyssey (1968)                                          0.112141
# 21 Grams (2003)                                                       0.145272
#
# title                                               You've Got Mail (1998)  \
# title
# (500) Days of Summer (2009)                                       0.140981
# 10 Cloverfield Lane (2016)                                        0.041093
# 10 Things I Hate About You (1999)                                 0.247940
# 101 Dalmatians (1996)                                             0.162952
# 101 Dalmatians (One Hundred and One Dalmatians)...                0.209313
# 12 Angry Men (1957)                                               0.078347
# 127 Hours (2010)                                                  0.015838
# 13 Going on 30 (2004)                                             0.138332
# 2001: A Space Odyssey (1968)                                      0.171466
# 21 Grams (2003)                                                   0.053785
#
# title                                               Young Frankenstein (1974)  \
# title
# (500) Days of Summer (2009)                                          0.066077
# 10 Cloverfield Lane (2016)                                           0.005034
# 10 Things I Hate About You (1999)                                    0.144038
# 101 Dalmatians (1996)                                                0.177214
# 101 Dalmatians (One Hundred and One Dalmatians)...                   0.180318
# 12 Angry Men (1957)                                                  0.135876
# 127 Hours (2010)                                                     0.003485
# 13 Going on 30 (2004)                                                0.018590
# 2001: A Space Odyssey (1968)                                         0.313117
# 21 Grams (2003)                                                      0.109025
#
# title                                               Zack and Miri Make a Porno (2008)  \
# title
# (500) Days of Summer (2009)                                                  0.374515
# 10 Cloverfield Lane (2016)                                                   0.242663
# 10 Things I Hate About You (1999)                                            0.243118
# 101 Dalmatians (1996)                                                        0.114968
# 101 Dalmatians (One Hundred and One Dalmatians)...                           0.120302
# 12 Angry Men (1957)                                                          0.104518
# 127 Hours (2010)                                                             0.223135
# 13 Going on 30 (2004)                                                        0.103892
# 2001: A Space Odyssey (1968)                                                 0.150649
# 21 Grams (2003)                                                              0.124965
#
# title                                               Zelig (1983)  \
# title
# (500) Days of Summer (2009)                             0.051286
# 10 Cloverfield Lane (2016)                             -0.016160
# 10 Things I Hate About You (1999)                       0.101622
# 101 Dalmatians (1996)                                   0.091345
# 101 Dalmatians (One Hundred and One Dalmatians)...      0.150069
# 12 Angry Men (1957)                                     0.134480
# 127 Hours (2010)                                       -0.018288
# 13 Going on 30 (2004)                                   0.048055
# 2001: A Space Odyssey (1968)                            0.217489
# 21 Grams (2003)                                         0.229073
#
# title                                               Zero Dark Thirty (2012)  \
# title
# (500) Days of Summer (2009)                                        0.178655
# 10 Cloverfield Lane (2016)                                         0.099059
# 10 Things I Hate About You (1999)                                  0.104858
# 101 Dalmatians (1996)                                              0.077232
# 101 Dalmatians (One Hundred and One Dalmatians)...                 0.125816
# 12 Angry Men (1957)                                                0.028415
# 127 Hours (2010)                                                   0.154299
# 13 Going on 30 (2004)                                              0.171578
# 2001: A Space Odyssey (1968)                                       0.097214
# 21 Grams (2003)                                                    0.032101
#
# title                                               Zombieland (2009)  \
# title
# (500) Days of Summer (2009)                                  0.355723
# 10 Cloverfield Lane (2016)                                   0.241751
# 10 Things I Hate About You (1999)                            0.158637
# 101 Dalmatians (1996)                                        0.113224
# 101 Dalmatians (One Hundred and One Dalmatians)...           0.171654
# 12 Angry Men (1957)                                          0.144652
# 127 Hours (2010)                                             0.198926
# 13 Going on 30 (2004)                                        0.108230
# 2001: A Space Odyssey (1968)                                 0.196175
# 21 Grams (2003)                                              0.055743
#
# title                                               Zoolander (2001)  \
# title
# (500) Days of Summer (2009)                                 0.252226
# 10 Cloverfield Lane (2016)                                  0.195054
# 10 Things I Hate About You (1999)                           0.281934
# 101 Dalmatians (1996)                                       0.184324
# 101 Dalmatians (One Hundred and One Dalmatians)...          0.274260
# 12 Angry Men (1957)                                         0.122107
# 127 Hours (2010)                                            0.091416
# 13 Going on 30 (2004)                                       0.225685
# 2001: A Space Odyssey (1968)                                0.148409
# 21 Grams (2003)                                             0.111366
#
# title                                               eXistenZ (1999)
# title
# (500) Days of Summer (2009)                                0.053614
# 10 Cloverfield Lane (2016)                                 0.177846
# 10 Things I Hate About You (1999)                          0.121029
# 101 Dalmatians (1996)                                      0.047804
# 101 Dalmatians (One Hundred and One Dalmatians)...         0.085606
# 12 Angry Men (1957)                                       -0.001708
# 127 Hours (2010)                                           0.128638
# 13 Going on 30 (2004)                                      0.010007
# 2001: A Space Odyssey (1968)                               0.306034
# 21 Grams (2003)                                            0.242192
#
# [10 rows x 1119 columns]

# %% [markdown]
# # Creating Function to Recommend Movies
# Now a function recommender() is created in order to carry out the recommending of movies. This function  takes in two inputs, a movie name and a rating. First, it calculates the correlation between the input movie and all other movies in the dataset using the Pearson correlation method. This gives us a correlation score between the input movie and all other movies in the dataset.
#
# Then it multiplies these correlation scores by the difference of the input rating and 2.5. This is done to give more weight to the movies that are rated highly by the user.
#
# Finally, the function sorts the resulting similarity scores in descending order and returns the sorted similar ratings.

# %%
#creating function to carry out recommending
def recommender(movie_name,rating):
    similar_ratings = corrMatrix[movie_name]*(rating-2.5)
    similar_ratings = similar_ratings.sort_values(ascending=False)
    #print(type(similar_ratings))
    return similar_ratings

# %% [markdown]
# # Checking the Result with Dummy Data
# After the function is created it is now used in the dummy data that was written for the testing of the fucntion. Below a series of romantic movies is rated high on the dummy data. Hence, after running the algorithm there should be recommendation of romantic movies which was achieved as seen below. Which concludes the system was working fine.

# %%
# creating dummy data to test the system
dummy_data = [("(500) Days of Summer (2009)",5),("Leaving Las Vegas (1995)",4),("Aliens (1986)",1),("2001: A Space Odyssey (1968)",2)]
recommended = pd.DataFrame()
for movie,rating in dummy_data:
    recommended = pd.concat([recommender(movie,rating) for movie,rating in dummy_data], axis=0)
    
recommended.head(10)
# Out:
# title
# (500) Days of Summer (2009)           2.500000
# Scott Pilgrim vs. the World (2010)    1.032022
# Hangover                              1.015052
# I Love You                            1.001149
# Moonrise Kingdom (2012)               0.972756
# Burn After Reading (2008)             0.956260
# Notebook                              0.952151
# Juno (2007)                           0.947093
# Spanglish (2004)                      0.941843
# Zack and Miri Make a Porno (2008)     0.936288
# dtype: float64

# %% [markdown]
# #  Performance Metrics
# As this is user-based collaborative filtering i.e. regression problem, hence, it is necessary to calculate the performance metrics for the problem. It includes calculation of <b>MAE</b>(Mean Absolute Error), <b>MSE</b>(Mean Squared Error) and <b>RMSE</b>(Root Mean Square Error). These calculation are done below in the function named performance_metrics(). For the calculation of this metrics, it is necessary to have the predicted ratings of the movie along with the actual movie. Then using their respective formulas for the calculation.

# %%
def performance_metrics(predicted_ratings, actual_ratings):
    mae = mean_absolute_error(predicted_ratings, actual_ratings)
    mse = mean_squared_error(predicted_ratings, actual_ratings)
    rmse = sqrt(mse)
    return {'MAE': mae, 'MSE': mse, 'RMSE': rmse}

# Using the function
predicted_ratings = recommended[:3000]
print (predicted_ratings.shape)

actual_ratings = user_ratings[user_ratings['title'].isin(recommended.index)]['rating'][:3000]
print (actual_ratings.shape)

metrics = performance_metrics(predicted_ratings, actual_ratings)

print("Mean Absolute Error (MAE): ", metrics['MAE'])
print("Mean Squared Error (MSE): ", metrics['MSE'])
print("Root Mean Squared Error (RMSE): ", metrics['RMSE'])
# Out:
# (3000,)
# (3000,)
# Mean Absolute Error (MAE):  3.6521624320978368
# Mean Squared Error (MSE):  14.237474478057697
# Root Mean Squared Error (RMSE):  3.77325780699619

# %% [markdown]
# # Confusion Metrics
# The confusion matrix is used for classification problems and it is used to evaluate the accuracy of a classification model. But in this case, the system is not performing a classification problem but a collaborative filtering problem (regression problem) . Therefore, it doesn't make sense to use the confusion matrix.
